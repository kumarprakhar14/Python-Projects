# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Data2.csv')

# %%
data.head()
# Out:
#   State Identifer       FY  Agriculture  Barren land  Buildup(Mining)  \
# 0              UP  2005-06    187013.85       687.72            98.53
# 1              UP  2011-12    194583.39      7587.55           367.92
# 2              UP  2015-16    194498.37       219.60           407.55
# 3              AP  2005-06    166112.16      3297.70           740.19
# 4              AP  2011-12     95892.25     15585.19           446.52
#
#    Buildup(Rural)  Buildup(Urban)    Forest  Wet lands  GDP_Agric  \
# 0         7001.23         4141.60  12618.51   11362.04    2973694
# 1         8258.82         3921.13  15485.14   10567.19    8726191
# 2         8289.32         4101.90  15469.85   10569.58   12645300
# 3         4922.85         2596.83  59550.71   18582.09    3128389
# 4         2926.42         1503.12  34572.64   11965.12    3904992
#
#    GDP_Industry  GDP_Service   TotalGDP Unnamed: 13
# 0       5460143     13135777   27781788         NaN
# 1       9640976     22578126   41840413         NaN
# 2       9716501     41693882  113780794         NaN
# 3       2489325      7126015   14197662         NaN
# 4       5091104     11875005   22128548         NaN

# %%
data = data.drop(['Unnamed: 13'], axis=1)

# %%
data.head()
# Out:
#   State Identifer       FY  Agriculture  Barren land  Buildup(Mining)  \
# 0              UP  2005-06    187013.85       687.72            98.53
# 1              UP  2011-12    194583.39      7587.55           367.92
# 2              UP  2015-16    194498.37       219.60           407.55
# 3              AP  2005-06    166112.16      3297.70           740.19
# 4              AP  2011-12     95892.25     15585.19           446.52
#
#    Buildup(Rural)  Buildup(Urban)    Forest  Wet lands  GDP_Agric  \
# 0         7001.23         4141.60  12618.51   11362.04    2973694
# 1         8258.82         3921.13  15485.14   10567.19    8726191
# 2         8289.32         4101.90  15469.85   10569.58   12645300
# 3         4922.85         2596.83  59550.71   18582.09    3128389
# 4         2926.42         1503.12  34572.64   11965.12    3904992
#
#    GDP_Industry  GDP_Service   TotalGDP
# 0       5460143     13135777   27781788
# 1       9640976     22578126   41840413
# 2       9716501     41693882  113780794
# 3       2489325      7126015   14197662
# 4       5091104     11875005   22128548

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(20,12))
plt.plot(data['Agriculture'],data['GDP_Agric'], 's-b')
plt.plot(data['Agriculture'], data['TotalGDP'], 'o--r')
plt.xlabel('Agriculture Land')
plt.ylabel("GDP")
plt.legend(['GDP_Agric', 'TotalGDP']);

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
data['State Identifer'] = encoder.fit_transform(data['State Identifer'])

# %%
data.head()
# Out:
#    State Identifer       FY  Agriculture  Barren land  Buildup(Mining)  \
# 0                5  2005-06    187013.85       687.72            98.53
# 1                5  2011-12    194583.39      7587.55           367.92
# 2                5  2015-16    194498.37       219.60           407.55
# 3                0  2005-06    166112.16      3297.70           740.19
# 4                0  2011-12     95892.25     15585.19           446.52
#
#    Buildup(Rural)  Buildup(Urban)    Forest  Wet lands  GDP_Agric  \
# 0         7001.23         4141.60  12618.51   11362.04    2973694
# 1         8258.82         3921.13  15485.14   10567.19    8726191
# 2         8289.32         4101.90  15469.85   10569.58   12645300
# 3         4922.85         2596.83  59550.71   18582.09    3128389
# 4         2926.42         1503.12  34572.64   11965.12    3904992
#
#    GDP_Industry  GDP_Service   TotalGDP
# 0       5460143     13135777   27781788
# 1       9640976     22578126   41840413
# 2       9716501     41693882  113780794
# 3       2489325      7126015   14197662
# 4       5091104     11875005   22128548

# %%
data['FY'] = encoder.fit_transform(data['FY'])

# %%
data.head()
# Out:
#    State Identifer  FY  Agriculture  Barren land  Buildup(Mining)  \
# 0                5   0    187013.85       687.72            98.53
# 1                5   1    194583.39      7587.55           367.92
# 2                5   2    194498.37       219.60           407.55
# 3                0   0    166112.16      3297.70           740.19
# 4                0   1     95892.25     15585.19           446.52
#
#    Buildup(Rural)  Buildup(Urban)    Forest  Wet lands  GDP_Agric  \
# 0         7001.23         4141.60  12618.51   11362.04    2973694
# 1         8258.82         3921.13  15485.14   10567.19    8726191
# 2         8289.32         4101.90  15469.85   10569.58   12645300
# 3         4922.85         2596.83  59550.71   18582.09    3128389
# 4         2926.42         1503.12  34572.64   11965.12    3904992
#
#    GDP_Industry  GDP_Service   TotalGDP
# 0       5460143     13135777   27781788
# 1       9640976     22578126   41840413
# 2       9716501     41693882  113780794
# 3       2489325      7126015   14197662
# 4       5091104     11875005   22128548

# %%
data.corr()
# Out:
#                  State Identifer            FY  Agriculture  Barren land  \
# State Identifer     1.000000e+00  2.653941e-17     0.474065    -0.141501
# FY                  2.653941e-17  1.000000e+00    -0.081502     0.172997
# Agriculture         4.740654e-01 -8.150209e-02     1.000000     0.120642
# Barren land        -1.415014e-01  1.729966e-01     0.120642     1.000000
# Buildup(Mining)    -9.698612e-02  2.740754e-01    -0.140730    -0.044775
# Buildup(Rural)      7.566596e-01 -6.466106e-02     0.432717    -0.149984
# Buildup(Urban)      6.886354e-01  1.626005e-01     0.746426     0.154127
# Forest              2.371431e-03  5.478696e-02    -0.091260    -0.050050
# Wet lands           2.123850e-01 -8.490057e-03    -0.174479    -0.010309
# GDP_Agric           4.375987e-01  5.947000e-01     0.560824     0.170104
# GDP_Industry        4.655976e-01  6.407864e-02     0.486941     0.498833
# GDP_Service         4.340338e-01  5.256362e-01     0.557678     0.111993
# TotalGDP            4.023550e-01  6.454320e-01     0.498508     0.101966
#
#                  Buildup(Mining)  Buildup(Rural)  Buildup(Urban)    Forest  \
# State Identifer        -0.096986        0.756660        0.688635  0.002371
# FY                      0.274075       -0.064661        0.162600  0.054787
# Agriculture            -0.140730        0.432717        0.746426 -0.091260
# Barren land            -0.044775       -0.149984        0.154127 -0.050050
# Buildup(Mining)         1.000000        0.086517        0.307658  0.429554
# Buildup(Rural)          0.086517        1.000000        0.539100  0.037735
# Buildup(Urban)          0.307658        0.539100        1.000000  0.057223
# Forest                  0.429554        0.037735        0.057223  1.000000
# Wet lands               0.224896        0.236073        0.011037  0.863428
# GDP_Agric              -0.082911        0.431196        0.509524 -0.204780
# GDP_Industry           -0.039681        0.233420        0.508086  0.238093
# GDP_Service             0.031404        0.236420        0.583194  0.109781
# TotalGDP                0.006636        0.229988        0.541318 -0.013622
#
#                  Wet lands  GDP_Agric  GDP_Industry  GDP_Service  TotalGDP
# State Identifer   0.212385   0.437599      0.465598     0.434034  0.402355
# FY               -0.008490   0.594700      0.064079     0.525636  0.645432
# Agriculture      -0.174479   0.560824      0.486941     0.557678  0.498508
# Barren land      -0.010309   0.170104      0.498833     0.111993  0.101966
# Buildup(Mining)   0.224896  -0.082911     -0.039681     0.031404  0.006636
# Buildup(Rural)    0.236073   0.431196      0.233420     0.236420  0.229988
# Buildup(Urban)    0.011037   0.509524      0.508086     0.583194  0.541318
# Forest            0.863428  -0.204780      0.238093     0.109781 -0.013622
# Wet lands         1.000000  -0.111169      0.241465     0.040052 -0.034816
# GDP_Agric        -0.111169   1.000000      0.273340     0.673800  0.787641
# GDP_Industry      0.241465   0.273340      1.000000     0.547018  0.392348
# GDP_Service       0.040052   0.673800      0.547018     1.000000  0.957201
# TotalGDP         -0.034816   0.787641      0.392348     0.957201  1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
X = data.drop(['TotalGDP'], axis=1)
y = data['TotalGDP']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=True)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
accuracy = model.score(X_test, y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: -26.130984156961166

# %%
ans = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, ans)

# %%
score
# Out:
# -26.130984156961166
